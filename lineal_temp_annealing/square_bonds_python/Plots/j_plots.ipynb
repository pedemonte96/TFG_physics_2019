# %%
# imports
import numpy as np
import random
import math
import timeit
import matplotlib.pyplot as plt
from tqdm import tqdm_notebook

# %%
def write_error_to_file(filename, error):
    f = open(filename, "w+")
    for e in error:
        f.write(str(e)+"\n")
    f.close()
def read_error_from_file(filename):
    with open(filename, 'r') as fp:
        s = fp.readlines()
    return np.array([e.strip() for e in s], dtype='float')

# %%
def write_arr_to_file(filename, arr1, arr2):
    f = open(filename, "w+")
    for e1, e2 in zip(arr1, arr2):
        f.write(str(e1)+' '+str(e2)+"\n")
    f.close()
def read_arr_from_file(filename):
    arr1 = []
    arr2 = []
    with open(filename, 'r') as fp:
        s = fp.readlines()
    for e in s:
        arr1.append(e.split()[0])
        arr2.append(e.split()[1])

    return np.array(arr1, dtype='float'), np.array(arr2, dtype='float')

def mean_error(h, j, hp, jp, magnetic_field=True):
    n, = h.shape
    numerator = np.linalg.norm(j - jp)**2 + np.linalg.norm(h-hp)**2
    denominator = np.linalg.norm(jp)**2 + np.linalg.norm(hp)**2
    return np.sqrt(numerator/denominator)

# %%
j0_L4_T1_S1, j_L4_T1_S1 = read_arr_from_file('M25000_L4_T1_S1_j.txt')
j0_L4_T1_S2, j_L4_T1_S2 = read_arr_from_file('M25000_L4_T1_S2_j.txt')
j0_L4_T1_S3, j_L4_T1_S3 = read_arr_from_file('M25000_L4_T1_S3_j.txt')
j0_L4_T2_S1, j_L4_T2_S1 = read_arr_from_file('M25000_L4_T2_S1_j.txt')
j0_L4_T2_S2, j_L4_T2_S2 = read_arr_from_file('M25000_L4_T2_S2_j.txt')
j0_L4_T2_S3, j_L4_T2_S3 = read_arr_from_file('M25000_L4_T2_S3_j.txt')
j0_L4_T3_S1, j_L4_T3_S1 = read_arr_from_file('M25000_L4_T3_S1_j.txt')
j0_L4_T3_S2, j_L4_T3_S2 = read_arr_from_file('M25000_L4_T3_S2_j.txt')
j0_L4_T3_S3, j_L4_T3_S3 = read_arr_from_file('M25000_L4_T3_S3_j.txt')
j0_L8_T1_S1, j_L8_T1_S1 = read_arr_from_file('M25000_L8_T1_S1_j.txt')
j0_L8_T1_S2, j_L8_T1_S2 = read_arr_from_file('M25000_L8_T1_S2_j.txt')
j0_L8_T1_S3, j_L8_T1_S3 = read_arr_from_file('M25000_L8_T1_S3_j.txt')
j0_L8_T2_S1, j_L8_T2_S1 = read_arr_from_file('M25000_L8_T2_S1_j.txt')
j0_L8_T2_S2, j_L8_T2_S2 = read_arr_from_file('M25000_L8_T2_S2_j.txt')
j0_L8_T2_S3, j_L8_T2_S3 = read_arr_from_file('M25000_L8_T2_S3_j.txt')
j0_L8_T3_S1, j_L8_T3_S1 = read_arr_from_file('M25000_L8_T3_S1_j.txt')
j0_L8_T3_S2, j_L8_T3_S2 = read_arr_from_file('M25000_L8_T3_S2_j.txt')
j0_L8_T3_S3, j_L8_T3_S3 = read_arr_from_file('M25000_L8_T3_S3_j.txt')
h = np.zeros(int(len(j0_L4_T1_S1)/2))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a6291ef82d6c> in <module>()
# ----> 1 j0_L4_T1_S1, j_L4_T1_S1 = read_arr_from_file('M25000_L4_T1_S1_j.txt')
#       2 j0_L4_T1_S2, j_L4_T1_S2 = read_arr_from_file('M25000_L4_T1_S2_j.txt')
#       3 j0_L4_T1_S3, j_L4_T1_S3 = read_arr_from_file('M25000_L4_T1_S3_j.txt')
#       4 j0_L4_T2_S1, j_L4_T2_S1 = read_arr_from_file('M25000_L4_T2_S1_j.txt')
#       5 j0_L4_T2_S2, j_L4_T2_S2 = read_arr_from_file('M25000_L4_T2_S2_j.txt')
#
# <ipython-input-3-0c8bd7654fe5> in read_arr_from_file(filename)
#       7     arr1 = []
#       8     arr2 = []
# ----> 9     with open(filename, 'r') as fp:
#      10         s = fp.readlines()
#      11     for e in s:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'M25000_L4_T1_S1_j.txt'

# %%
print('L4_T1_S1_error:{}'.format(mean_error(h, j_L4_T1_S1, h, j0_L4_T1_S1)))
print('L4_T1_S2_error:{}'.format(mean_error(h, j_L4_T1_S2, h, j0_L4_T1_S2)))
print('L4_T1_S3_error:{}'.format(mean_error(h, j_L4_T1_S3, h, j0_L4_T1_S3)))
print('L4_T2_S1_error:{}'.format(mean_error(h, j_L4_T2_S1, h, j0_L4_T2_S1)))
print('L4_T2_S2_error:{}'.format(mean_error(h, j_L4_T2_S2, h, j0_L4_T2_S2)))
print('L4_T2_S3_error:{}'.format(mean_error(h, j_L4_T2_S3, h, j0_L4_T2_S3)))
print('L4_T3_S1_error:{}'.format(mean_error(h, j_L4_T3_S1, h, j0_L4_T3_S1)))
print('L4_T3_S2_error:{}'.format(mean_error(h, j_L4_T3_S2, h, j0_L4_T3_S2)))
print('L4_T3_S3_error:{}'.format(mean_error(h, j_L4_T3_S3, h, j0_L4_T3_S3)))
print('L8_T1_S1_error:{}'.format(mean_error(h, j_L8_T1_S1, h, j0_L8_T1_S1)))
print('L8_T1_S2_error:{}'.format(mean_error(h, j_L8_T1_S2, h, j0_L8_T1_S2)))
print('L8_T1_S3_error:{}'.format(mean_error(h, j_L8_T1_S3, h, j0_L8_T1_S3)))
print('L8_T2_S1_error:{}'.format(mean_error(h, j_L8_T2_S1, h, j0_L8_T2_S1)))
print('L8_T2_S2_error:{}'.format(mean_error(h, j_L8_T2_S2, h, j0_L8_T2_S2)))
print('L8_T2_S3_error:{}'.format(mean_error(h, j_L8_T2_S3, h, j0_L8_T2_S3)))
print('L8_T3_S1_error:{}'.format(mean_error(h, j_L8_T3_S1, h, j0_L8_T3_S1)))
print('L8_T3_S2_error:{}'.format(mean_error(h, j_L8_T3_S2, h, j0_L8_T3_S2)))
print('L8_T3_S3_error:{}'.format(mean_error(h, j_L8_T3_S3, h, j0_L8_T3_S3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6bb1273d66e8> in <module>()
# ----> 1 print('L4_T1_S1_error:{}'.format(mean_error(h, j_L4_T1_S1, h, j0_L4_T1_S1)))
#       2 print('L4_T1_S2_error:{}'.format(mean_error(h, j_L4_T1_S2, h, j0_L4_T1_S2)))
#       3 print('L4_T1_S3_error:{}'.format(mean_error(h, j_L4_T1_S3, h, j0_L4_T1_S3)))
#       4 print('L4_T2_S1_error:{}'.format(mean_error(h, j_L4_T2_S1, h, j0_L4_T2_S1)))
#       5 print('L4_T2_S2_error:{}'.format(mean_error(h, j_L4_T2_S2, h, j0_L4_T2_S2)))
#
# NameError: name 'h' is not defined

# %%
j0, j = read_arr_from_file('M25000_L32_T2_S1_j.txt')
print(len(j0), len(j))
# Out:
# 2048 2048

# %%
from matplotlib import rc
import matplotlib
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'

# %%
color1, color2, color3 = '#bb0000', '#00bb00', '#0000bb'
color_line = '#555555'

# %%
plt.figure(figsize = (14, 10))
mk_size=50
ax = plt.axes()
plt.title(r'L=32, $\beta=\beta_2$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.15, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0, j-j0, color=color2, label='Sample 1', zorder=6, marker="o", s=mk_size)
#plt.scatter(j0_L4_T1_S2, j_L4_T1_S2-j0_L4_T1_S2, color=color1, label='Sample 1', zorder=5, marker="d", s=mk_size)
#plt.scatter(j0_L4_T1_S3, j_L4_T1_S3-j0_L4_T1_S3, color=color1, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.05, 0.05)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L32_T2.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j-j0)))
#print(max(abs(j_L4_T1_S2-j0_L4_T1_S2)))
#print(max(abs(j_L4_T1_S3-j0_L4_T1_S3)))
# Out:
# 0.038955043212671625

# %%
plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=8, $\beta=\beta_1$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L8_T1_S1, j_L8_T1_S1-j0_L8_T1_S1, color=color1, label='Sample 1', zorder=6, marker="o", s=mk_size)
plt.scatter(j0_L8_T1_S2, j_L8_T1_S2-j0_L8_T1_S2, color=color1, label='Sample 1', zorder=5, marker="d", s=mk_size)
plt.scatter(j0_L8_T1_S3, j_L8_T1_S3-j0_L8_T1_S3, color=color1, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.4, 0.4)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.02))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L8_T1.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L8_T1_S1-j0_L8_T1_S1)))
print(max(abs(j_L8_T1_S2-j0_L8_T1_S2)))
print(max(abs(j_L8_T1_S3-j0_L8_T1_S3)))
# Out:
# 0.36570453731220637
# 0.0880106413907693
# 0.24815525781414294

# %%
plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=4, $\beta=\beta_2$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L4_T2_S1, j_L4_T2_S1-j0_L4_T2_S1, color=color2, label='Sample 1', zorder=6, marker="o", s=mk_size)
plt.scatter(j0_L4_T2_S2, j_L4_T2_S2-j0_L4_T2_S2, color=color2, label='Sample 1', zorder=5, marker="d", s=mk_size)
plt.scatter(j0_L4_T2_S3, j_L4_T2_S3-j0_L4_T2_S3, color=color2, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.05, 0.05)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L4_T2.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L4_T2_S1-j0_L4_T2_S1)))
print(max(abs(j_L4_T2_S2-j0_L4_T2_S2)))
print(max(abs(j_L4_T2_S3-j0_L4_T2_S3)))
# Out:
# 0.036486506605228564
# 0.02424428494348696
# 0.02404306863140082

# %%
plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=8, $\beta=\beta_2$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L8_T2_S1, j_L8_T2_S1-j0_L8_T2_S1, color=color2, label='Sample 1', zorder=6, marker="o", s=mk_size)
plt.scatter(j0_L8_T2_S2, j_L8_T2_S2-j0_L8_T2_S2, color=color2, label='Sample 1', zorder=5, marker="d", s=mk_size)
plt.scatter(j0_L8_T2_S3, j_L8_T2_S3-j0_L8_T2_S3, color=color2, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.05, 0.05)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L8_T2.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L8_T2_S1-j0_L8_T2_S1)))
print(max(abs(j_L8_T2_S2-j0_L8_T2_S2)))
print(max(abs(j_L8_T2_S3-j0_L8_T2_S3)))
# Out:
# 0.023180432203422474
# 0.03193460440448548
# 0.03243723516210628

# %%
plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=4, $\beta=\beta_3$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L4_T3_S1, j_L4_T3_S1-j0_L4_T3_S1, color=color3, label='Sample 1', zorder=6, marker="o", s=mk_size)
plt.scatter(j0_L4_T3_S2, j_L4_T3_S2-j0_L4_T3_S2, color=color3, label='Sample 1', zorder=5, marker="d", s=mk_size)
plt.scatter(j0_L4_T3_S3, j_L4_T3_S3-j0_L4_T3_S3, color=color3, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.05, 0.05)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L4_T3.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L4_T3_S1-j0_L4_T3_S1)))
print(max(abs(j_L4_T3_S2-j0_L4_T3_S2)))
print(max(abs(j_L4_T3_S3-j0_L4_T3_S3)))
# Out:
# 0.04044842356500622
# 0.03974104812270174
# 0.023584494453564815

# %%
plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=8, $\beta=\beta_3$', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L8_T3_S1, j_L8_T3_S1-j0_L8_T3_S1, color=color3, label='Sample 1', zorder=6, marker="o", s=mk_size)
plt.scatter(j0_L8_T3_S2, j_L8_T3_S2-j0_L8_T3_S2, color=color3, label='Sample 1', zorder=5, marker="d", s=mk_size)
plt.scatter(j0_L8_T3_S3, j_L8_T3_S3-j0_L8_T3_S3, color=color3, label='Sample 1', zorder=4, marker="^", s=mk_size)


plt.ylim(-0.05, 0.05)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L8_T3.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L8_T3_S1-j0_L8_T3_S1)))
print(max(abs(j_L8_T3_S2-j0_L8_T3_S2)))
print(max(abs(j_L8_T3_S3-j0_L8_T3_S3)))
# Out:
# 0.03946274846782827
# 0.03941930294960849
# 0.035043033771672956

# %%
#write_arr_to_file('M25000_L4_T1_S1_j.txt', flat_matrix(j1), flat_matrix(result1[0][1]))
#write_arr_to_file('M25000_L4_T1_S2_j.txt', flat_matrix(j2), flat_matrix(result2[0][1]))
#write_arr_to_file('M25000_L4_T1_S3_j.txt', flat_matrix(j3), flat_matrix(result3[0][1]))

# %%
#test

plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=4', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L4_T1_S1, j_L4_T1_S1-j0_L4_T1_S1, color=color1, label='Sample 1', zorder=2, marker="o", s=mk_size)
plt.scatter(j0_L4_T1_S2, j_L4_T1_S2-j0_L4_T1_S2, color=color1, label='Sample 1', zorder=3, marker="d", s=mk_size)
plt.scatter(j0_L4_T1_S3, j_L4_T1_S3-j0_L4_T1_S3, color=color1, label='Sample 1', zorder=4, marker="^", s=mk_size)
plt.scatter(j0_L4_T2_S1, j_L4_T2_S1-j0_L4_T2_S1, color=color2, label='Sample 1', zorder=8, marker="o", s=mk_size)
plt.scatter(j0_L4_T2_S2, j_L4_T2_S2-j0_L4_T2_S2, color=color2, label='Sample 1', zorder=9, marker="d", s=mk_size)
plt.scatter(j0_L4_T2_S3, j_L4_T2_S3-j0_L4_T2_S3, color=color2, label='Sample 1', zorder=10, marker="^", s=mk_size)
plt.scatter(j0_L4_T3_S1, j_L4_T3_S1-j0_L4_T3_S1, color=color3, label='Sample 1', zorder=5, marker="o", s=mk_size)
plt.scatter(j0_L4_T3_S2, j_L4_T3_S2-j0_L4_T3_S2, color=color3, label='Sample 1', zorder=6, marker="d", s=mk_size)
plt.scatter(j0_L4_T3_S3, j_L4_T3_S3-j0_L4_T3_S3, color=color3, label='Sample 1', zorder=7, marker="^", s=mk_size)


plt.ylim(-0.1, 0.1)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.05))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.01))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L4_test_all.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L4_T1_S1-j0_L4_T1_S1)))
print(max(abs(j_L4_T1_S2-j0_L4_T1_S2)))
print(max(abs(j_L4_T1_S3-j0_L4_T1_S3)))
# Out:
# 0.09205698942605367
# 0.03709188347302328
# 0.06354356539945744

# %%
#test

plt.figure(figsize = (10, 10))
mk_size=200
ax = plt.axes()
plt.title(r'L=8', fontsize=45, y=1.005)
plt.xlabel(r'$J^{0}_{ij}$', rotation=0, fontsize=45)
plt.ylabel(r'$\Delta J_{ij}$', rotation=0, fontsize=45)
ax.xaxis.set_label_coords(0.5, -0.1)
ax.yaxis.set_label_coords(-0.2, 0.5)
plt.plot((-1, 1), (0,0), color=color_line, label='y=x', zorder=1, linewidth=3, alpha=1)
plt.scatter(j0_L8_T1_S1, j_L8_T1_S1-j0_L8_T1_S1, color=color1, label='Sample 1', zorder=2, marker="o", s=mk_size)
plt.scatter(j0_L8_T1_S2, j_L8_T1_S2-j0_L8_T1_S2, color=color1, label='Sample 1', zorder=3, marker="d", s=mk_size)
plt.scatter(j0_L8_T1_S3, j_L8_T1_S3-j0_L8_T1_S3, color=color1, label='Sample 1', zorder=4, marker="^", s=mk_size)
plt.scatter(j0_L8_T2_S1, j_L8_T2_S1-j0_L8_T2_S1, color=color2, label='Sample 1', zorder=8, marker="o", s=mk_size)
plt.scatter(j0_L8_T2_S2, j_L8_T2_S2-j0_L8_T2_S2, color=color2, label='Sample 1', zorder=9, marker="d", s=mk_size)
plt.scatter(j0_L8_T2_S3, j_L8_T2_S3-j0_L8_T2_S3, color=color2, label='Sample 1', zorder=10, marker="^", s=mk_size)
plt.scatter(j0_L8_T3_S1, j_L8_T3_S1-j0_L8_T3_S1, color=color3, label='Sample 1', zorder=5, marker="o", s=mk_size)
plt.scatter(j0_L8_T3_S2, j_L8_T3_S2-j0_L8_T3_S2, color=color3, label='Sample 1', zorder=6, marker="d", s=mk_size)
plt.scatter(j0_L8_T3_S3, j_L8_T3_S3-j0_L8_T3_S3, color=color3, label='Sample 1', zorder=7, marker="^", s=mk_size)


plt.ylim(-0.4, 0.4)
plt.xlim(-1, 1)

# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
# For the minor ticks, use no labels; default NullFormatter.
ax.xaxis.set_minor_locator(MultipleLocator(0.2))
# Make a plot with major ticks that are multiples of 20 and minor ticks that
# are multiples of 5.  Label major ticks with '%d' formatting but don't label
# minor ticks.
ax.yaxis.set_major_locator(MultipleLocator(0.1))
ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))
# For the minor ticks, use no labels; default NullFormatter.
ax.yaxis.set_minor_locator(MultipleLocator(0.02))
plt.xticks(fontsize=35)
plt.yticks(fontsize=35)
ax.tick_params(which='both', width=4)
ax.tick_params(which='major', length=12)
ax.tick_params(which='minor', length=7)
for axis in ['top','bottom','left','right']:
    ax.spines[axis].set_linewidth(4)
#plt.grid()
#plt.legend()
plt.savefig('L8_test_all.png', bbox_inches = 'tight')
plt.show()
print(max(abs(j_L4_T1_S1-j0_L4_T1_S1)))
print(max(abs(j_L4_T1_S2-j0_L4_T1_S2)))
print(max(abs(j_L4_T1_S3-j0_L4_T1_S3)))
# Out:
# 0.09205698942605367
# 0.03709188347302328
# 0.06354356539945744

# %%
from skimage import io, exposure, color, img_as_float, img_as_int, img_as_uint, img_as_ubyte
image = io.imread('test2.png')
def two_images(img1, img2, savename):
    io.imsave(savename, np.hstack((img1, img2)))
def three_images(img1, img2, img3, savename):
    io.imsave(savename, np.vstack((img1, img2, img3)))
two_images(image, image, 'test_joined.png')
image = io.imread('test_joined.png')
three_images(image, image, image, 'test_joined_final.png')
